# %% [markdown]
# # ETL de base com dados de inflação

# %%
import pandas as pd

# %%
df = pd.read_csv('data\\WHI_Inflation.csv', sep='\t')

# %%
df.head(10)
# Out:
#        Country  Year  Rank   Score  GDP per Capita  Social support  \
# 0  Afghanistan  2015   153  3.5750        0.319820        0.302850
# 1  Afghanistan  2016   154  3.3600        0.382270        0.110370
# 2  Afghanistan  2017   141  3.7940        0.401477        0.581543
# 3  Afghanistan  2018   145  3.6320        0.332000        0.537000
# 4  Afghanistan  2019   154  3.2030        0.350000        0.517000
# 5  Afghanistan  2020   153  2.5669        0.300706        0.470367
# 6  Afghanistan  2021   149  2.5230        7.695000        0.463000
# 7  Afghanistan  2022   146  2.4040        0.758000        0.000000
# 8  Afghanistan  2023   137  1.8590        7.324000        0.341000
# 9      Albania  2015    95  4.9590        0.878670        0.804340
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                          0.303350                      0.234140    0.365100
# ...

# %%
brasil = df[df['Country']=='Brazil']

# %%
brasil.head()
# Out:
#     Country  Year  Rank  Score  GDP per Capita  Social support  \
# 151  Brazil  2015    16  6.983        0.981240        1.232870
# 152  Brazil  2016    17  6.952        1.087540        1.039380
# 153  Brazil  2017    22  6.635        1.107353        1.431306
# 154  Brazil  2018    28  6.419        0.986000        1.474000
# 155  Brazil  2019    32  6.300        1.004000        1.439000
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 151                          0.697020                      0.490490
# 152                          0.614150                      0.404250
# 153                          0.616552                      0.437454
# 154                          0.675000                      0.493000
# 155                          0.802000                      0.390000
#
#      Generosity  Perceptions of corruption  Energy Consumer Price Inflation  \
# 151     0.14574                   0.175210                        16.759281
# ...
